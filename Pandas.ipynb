# %%
import pandas as pd
import numpy as np

# %%
#Syntax
x=pd.Series([1,2,3,4])
s=pd.Series([1,2,3,4], name='numbers',index = ['a','b','c','d'])
x
s
xs=x=pd.Series((1,2,3,4,5.5))
xs
a=np.array([1,2,3,4])
s=np.array(['a','b','c','d'])

# %%
from contextlib import AsyncContextDecorator
#Dataframe

d={'name':['Aayu','Moi','Toi'],
   'age':[21,22,20],
   'gender':['M','F','M'],
   'marks':[90,85,99]}
df=pd.DataFrame(d)#anything after value is considered index
#functions

#df.info()
#df.describe()
#df.columns

#df.head()
#df.tail() last 5 values

#df.unique() #works on categorical column
#df['gender'].unique() #only works in a single column at once

#df['gender'].value_counts()

#df.sort_values(by='marks',ascending=False)# by is mandate
#sorted_marks=df.sort_values(by='marks',ascending=False)
#sorted_marks.reset_index(inplace=True) #use only in dataframe and inplace is save in orginal data

#orted_marks.drop('index', axis=1)
# Out:
#    index  name  age gender  marks
# 0      2   Toi   20      M     99
# 1      0  Aayu   21      M     90
# 2      1   Moi   22      F     85

# %%
d={'name':['Aayu','Moi','Toi','Toji','Yuji'],
   'age':[21,22,20,25,24],
   'gender':['M','F','M','F','M'],
   'marks':[90,85,99,88,78]}
df=pd.DataFrame(d)
df['age'][::-1]
# Out:
# 4    24
# 3    25
# 2    20
# 1    22
# 0    21
# Name: age, dtype: int64

# %%
#loc
#df.loc(row,cols)

#df.loc[(0,1),['name','marks']] #row  slice end index in inclusive

#iloc
df.iloc[0:2,0:3]
# Out:
#    name  age gender
# 0  Aayu   21      M
# 1   Moi   22      F

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

s1 = Student("Aayush", 21)

print(s1.__dict__)
# Out:
# {'name': 'Aayush', 'age': 21}

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Taj1920/Data-Analysis-Datasets/refs/heads/main/Datasets-Practice/titanic.csv")
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...

# %%
#boolean filtering

#df[df['sex']=='female']
#df[(df['sex']=='female') & (df['age']==20)]
#df[((df['sex']=='female') & (df['age']==20)) | (df['fare']>500)]
# Out:
#       pclass                                               name     sex   age  \
# 49         1                 Cardeza, Mr. Thomas Drake Martinez    male  36.0
# 50         1  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0
# 183        1                             Lesurer, Mr. Gustave J    male  35.0
# 302        1                                   Ward, Miss. Anna  female  35.0
# 353        2                Bryhl, Miss. Dagmar Jenny Ingeborg   female  20.0
# 446        2                      Hocking, Miss. Ellen "Nellie"  female  20.0
# 559        2                               Sincock, Miss. Maude  female  20.0
# 687        3                       Braf, Miss. Elin Ester Maria  female  20.0
# 907        3                            Jussila, Miss. Katriina  female  20.0
# 1091       3                            Oreskovic, Miss. Marija  female  20.0
#
#       sibsp  parch      ticket      fare        cabin embarked  survived
# ...

# %%
#grouping

#df['sex'].unique()
#female=df.groupby('sex').get_group('female')

#df.groupby('embarked').get_group('C')

#fare=df[df['fare']>400]
#fare.groupby('sex').get_group('female')

#fare['name'].str.upper()
#df['fare'].sum()

#female_who=df.groupby('survived').get_group(1).groupby('sex').get_group('female')

#female_who[female_who['age']<18]

df.groupby(['sex','survived']).get_group(('female',0)).count()
# Out:
# pclass      127
# name        127
# sex         127
# age          96
# sibsp       127
# parch       127
# ticket      127
# fare        127
# cabin         8
# embarked    127
# survived    127
# dtype: int64

# %%
#drop rows or column
#sort
#reset
#applying ginbilt func

#handling missing value
#we can drop entire row where null/nan value is present
df.dropna()

#fill nan for integer or float data type - 0,mean,nan
#df['cabin']=df['cabin'].fillna('unknown').unique()
df['cabin']=df['cabin'].fillna('unknown') # to save and run

#filling with backward fill / forward fill
df['age'].fillna(method='ffill').count()
df['age'].fillna(method='bfill').count()

merged=pd.concat((df,df2),axis=1)


#duplicates
df.duplicated().value_counts()
df.drop_duplicates(inplace=True)


#conversion of a columns data type into another datatype
df['age'].astype(int)
