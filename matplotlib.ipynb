# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#

# %%
num =np.arange(1,11)
sq=num**2
cub=num**3

#plt.figure(flgsize=(10,3))

plt.title('linechart')

plt.plot(num,sq,marker='*')

plt.xlabel('numbers')
plt.ylabel('squares')
plt.xticks(range(1,11))
plt.show() #get clean output and get only graph

#annotation
#to show legend, put label inside plot
